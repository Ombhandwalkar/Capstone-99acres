# %%
import pandas as pd 
import numpy as np

# %%
house=pd.read_csv(r'B:\Major_Git\Capstone-99acres\data\external\house_cleaned.csv')
flats=pd.read_csv(r'B:\Major_Git\Capstone-99acres\data\external\flats_cleaned.csv')

# %%
df=pd.concat([house,flats],ignore_index=True)

# %%
# To shuffle the data mix in the dataset
df=df.sample(df.shape[0],ignore_index=True)

# %%
df.head(5)
# Out:
#                             property_name property_type  \
# 0         3 BHK Flat in Sector 92 Gurgaon          flat
# 1         4 BHK Flat in Sector 60 Gurgaon          flat
# 2        2 BHK Flat in Sector 102 Gurgaon          flat
# 3  5 Bedroom House for sale in New Colony         house
# 4           3 BHK Flat in Sector 36 Sohna          flat
#
#                                 society  price  price_per_sqft    area  \
# 0                            sare homes   0.60          5000.0  1200.0
# 1                            ireo skyon   3.60         12815.0  2809.0
# 2  shapoorji pallonji joyville gurugram   0.97         10601.0   915.0
# 3                         rattan garden   1.30         13499.0   963.0
# 4               signature global park 4   0.72          6428.0  1120.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                   Carpet area: 1200 (111.48 sq.m.)        3         2
# ...

# %%
df.to_csv('B:\Major_Git\Capstone-99acres\data\external\gurgaon_properties.csv',index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\ombha\AppData\Local\Temp\ipykernel_17128\3573472656.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df.to_csv('B:\Major_Git\Capstone-99acres\data\external\gurgaon_properties.csv',index=False)
